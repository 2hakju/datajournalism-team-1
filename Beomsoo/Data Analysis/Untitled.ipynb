# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

nd = pd.read_json("navertv_nahonja_2017.json", orient='records', encoding = 'utf-8')
md = pd.read_json("navertv_mudo_2017.json", orient='records', encoding = 'utf-8')
rd = pd.read_json("navertv_radiostar_2017.json", orient='records', encoding = 'utf-8')

md.date = pd.to_datetime(md.date)
nd.date = pd.to_datetime(nd.date)
rd.date = pd.to_datetime(rd.date)

md.head(20)
# Out:
#          date heart_count  is_park  is_yang  is_you  order_in_list play_count  \
# 0  2017-01-07         360     True    False   False              1    119,457
# 1  2017-01-07         271    False    False   False              2    100,333
# 2  2017-01-07         996    False    False   False              3    113,512
# 3  2017-01-07         364    False    False   False              4    156,732
# 4  2017-01-07         401    False    False   False              5    126,593
# 5  2017-01-07         353    False    False   False              6    119,415
# 6  2017-01-07         282    False    False   False              7     96,170
# 7  2017-01-07         297    False    False   False              8    131,016
# 8  2017-01-07         341    False    False   False              9    118,672
# 9  2017-01-07         333    False    False    True             10    115,547
# 10 2017-01-07         184    False    False   False             11    151,480
# ...
